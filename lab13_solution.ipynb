# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download ru_core_news_lg

# %%
import pandas as pd

# %%
df = pd.read_csv("poems.csv")
df = df.drop("poem", axis=1)
df = df.dropna()
df.head()
# Out:
#                      writer                                               text
# 1  Лермонтов Михаил Юрьевич  На серебряные шпоры\nЯ в раздумии гляжу;\nЗа т...
# 2  Лермонтов Михаил Юрьевич  Пилигрим\nАллах ли там среди пустыни\nЗастывши...
# 3  Лермонтов Михаил Юрьевич  О, не скрывай! Ты плакала об нем –\nИ я его лю...
# 4  Лермонтов Михаил Юрьевич  Ты знал ли дикий край, под знойными лучами,\nГ...
# 5  Лермонтов Михаил Юрьевич  Когда ты холодно внимаешь\nРассказам горести ч...

# %%
df.groupby(["writer"]).count().sort_values(by="text", ascending=False)
# Out:
#                                    text
# writer
# Брюсов Валерий Яковлевич           1607
# Игорь Северянин                    1597
# Александр Петрович Сумароков       1520
# Блок Александр Александрович       1282
# Маяковский Владимир Владимирович   1279
# Фёдор Кузьмич Сологуб              1163
# Бальмонт Константин Дмитриевич      990
# Фет Афанасий Афанасьевич            888
# Пушкин Александр Сергеевич          750
# Цветаева Марина Ивановна            535
# Лермонтов Михаил Юрьевич            414
# Тютчев Федор Иванович               398
# Некрасов Николай Алексеевич         398
# Андрей Белый                        394
# Есенин Сергей Александрович         391
# Аделаида Казимировна Герцык         351
# Пётр Андреевич Вяземский            338
# Алексей Николаевич Апухтин          334
# Ахматова Анна Андреевна             331
# Владислав Фелицианович Ходасевич    318
# Николай Михайлович Языков           307
# Иван Андреевич Крылов               292
# ...

# %%
group_1 = df.groupby(["writer"]).get_group("Брюсов Валерий Яковлевич")["text"].tolist()
group_0 = df.groupby(["writer"]).get_group("Фет Афанасий Афанасьевич")["text"].tolist()
group_0 += df.groupby(["writer"]).get_group("Пушкин Александр Сергеевич")["text"].tolist()

res_1 = [1 for i in range(len(group_1))]
res_0 = [0 for i in range(len(group_0))]

# %%
from sklearn.utils import shuffle

# %%
data = pd.DataFrame({"text": group_1 + group_0,
                     "result": res_1 + res_0})

data = shuffle(data, random_state=0).reset_index(drop=True)
data.head()
# Out:
#                                                 text  result
# 0  Есть улица в нашей столице.\nЕсть домик, и в д...       1
# 1  А лестница все круче…\nHe оступлюсь ли я?\nUrb...       1
# 2  На склоне у лона морской глубины\nСтояла стена...       0
# 3  1\nНедвижный страж дремал на царственном порог...       0
# 4  День — сей сияющий покров.\nТютчев\nВ последни...       1

# %%
import ru_core_news_lg
nlp = ru_core_news_lg.load()

# %%
data["pos"] = data["text"].apply(lambda x: nlp(x))

# %%
data["pos_names"] = data["pos"].apply(lambda x: [token.tag_ for token in x])

# %%
data.head()
# Out:
#                                                 text  result  \
# 0  Есть улица в нашей столице.\nЕсть домик, и в д...       1
# 1  А лестница все круче…\nHe оступлюсь ли я?\nUrb...       1
# 2  На склоне у лона морской глубины\nСтояла стена...       0
# 3  1\nНедвижный страж дремал на царственном порог...       0
# 4  День — сей сияющий покров.\nТютчев\nВ последни...       1
#
#                                                  pos  \
# 0  (Есть, улица, в, нашей, столице, ., \n, Есть, ...
# 1  (А, лестница, все, круче, …, \n, He, оступлюсь...
# 2  (На, склоне, у, лона, морской, глубины, \n, Ст...
# 3  (1, \n, Недвижный, страж, дремал, на, царствен...
# 4  (День, —, сей, сияющий, покров, ., \n, Тютчев,...
#
#                                            pos_names
# 0  [VERB, NOUN, ADP, DET, NOUN, PUNCT, SPACE, VER...
# 1  [CCONJ, NOUN, PART, ADJ, PUNCT, SPACE, PROPN, ...
# 2  [ADP, NOUN, ADP, NOUN, ADJ, NOUN, SPACE, VERB,...
# 3  [NUM, SPACE, ADJ, NOUN, VERB, ADP, ADJ, NOUN, ...
# ...

# %%
pos = set()
for item in data["pos_names"].values:
  pos.update(item)

# %%
for p in pos:
  data[p] = data["pos_names"].apply(lambda x: x.count(p))

# %%
data["pos_sum"] = [sum(data.iloc[i][4:]) for i in range(len(data))]

# %%
for i in range(5):
  for p in pos:
    data[p][i] = data.iloc[i][p] / data.iloc[i]["pos_sum"]

# %%
data.head()
# Out:
#                                                 text  result  \
# 0  Есть улица в нашей столице.\nЕсть домик, и в д...       1
# 1  А лестница все круче…\nHe оступлюсь ли я?\nUrb...       1
# 2  На склоне у лона морской глубины\nСтояла стена...       0
# 3  1\nНедвижный страж дремал на царственном порог...       0
# 4  День — сей сияющий покров.\nТютчев\nВ последни...       1
#
#                                                  pos  \
# 0  (Есть, улица, в, нашей, столице, ., \n, Есть, ...
# 1  (А, лестница, все, круче, …, \n, He, оступлюсь...
# 2  (На, склоне, у, лона, морской, глубины, \n, Ст...
# 3  (1, \n, Недвижный, страж, дремал, на, царствен...
# 4  (День, —, сей, сияющий, покров, ., \n, Тютчев,...
#
#                                            pos_names       AUX      PART  \
# 0  [VERB, NOUN, ADP, DET, NOUN, PUNCT, SPACE, VER...  0.009050  0.013575
# 1  [CCONJ, NOUN, PART, ADJ, PUNCT, SPACE, PROPN, ...  0.003891  0.027237
# ...

# %%
res_df = data.drop(["text", "pos", "pos_names", "pos_sum"], axis=1)
res_df.head()
# Out:
#    result       AUX      PART       DET         X     CCONJ      NOUN  \
# 0       1  0.009050  0.013575  0.045249  0.000000  0.045249  0.180995
# 1       1  0.003891  0.027237  0.035019  0.007782  0.046693  0.202335
# 2       0  0.000000  0.015504  0.015504  0.000000  0.046512  0.279070
# 3       0  0.004202  0.023109  0.014706  0.000000  0.046218  0.197479
# 4       1  0.000000  0.000000  0.020408  0.000000  0.040816  0.244898
#
#         ADV       ADP     INTJ      PRON       ADJ     PUNCT     PROPN  SYM  \
# 0  0.031674  0.090498  0.00905  0.076923  0.045249  0.158371  0.031674    0
# 1  0.062257  0.050584  0.00000  0.031128  0.077821  0.202335  0.031128    0
# 2  0.031008  0.077519  0.00000  0.007752  0.108527  0.124031  0.023256    0
# 3  0.029412  0.052521  0.00000  0.031513  0.075630  0.170168  0.077731    0
# 4  0.010204  0.061224  0.00000  0.071429  0.112245  0.204082  0.010204    0
#
#        VERB     SPACE       NUM     SCONJ
# 0  0.104072  0.140271  0.000000  0.018100
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(res_df)
scaled_data = pd.DataFrame(data=scaled_features, columns=res_df.columns)
scaled_data.head()
# Out:
#    result       AUX      PART       DET         X     CCONJ      NOUN  \
# 0     1.0  0.000171  0.000053  0.000209  0.000000  0.000107  0.000097
# 1     1.0  0.000073  0.000106  0.000162  0.000049  0.000110  0.000109
# 2     0.0  0.000000  0.000060  0.000072  0.000000  0.000110  0.000150
# 3     0.0  0.000079  0.000090  0.000068  0.000000  0.000109  0.000106
# 4     1.0  0.000000  0.000000  0.000094  0.000000  0.000096  0.000132
#
#         ADV       ADP      INTJ      PRON       ADJ     PUNCT     PROPN  SYM  \
# 0  0.000078  0.000144  0.000411  0.000124  0.000046  0.000015  0.000059  0.0
# 1  0.000153  0.000081  0.000000  0.000050  0.000078  0.000034  0.000058  0.0
# 2  0.000076  0.000123  0.000000  0.000013  0.000109  0.000000  0.000044  0.0
# 3  0.000072  0.000084  0.000000  0.000051  0.000076  0.000020  0.000146  0.0
# 4  0.000025  0.000097  0.000000  0.000115  0.000113  0.000035  0.000019  0.0
#
#        VERB     SPACE      NUM     SCONJ
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

# %%
x_train, x_test, y_train, y_test = train_test_split(scaled_data.drop(["result"], axis=1), scaled_data["result"],
                                                    test_size=0.2, random_state=42)

# %%
clf = SVC()
clf.fit(x_train, y_train)
y_prediction = clf.predict(x_test)

# %%
print("SVM", "\n")
print("precision_score:", precision_score(y_test, y_prediction) * 100, '%')
print("recall_score:", recall_score(y_test, y_prediction) * 100, '%')
print("f1_score:", f1_score(y_test, y_prediction) * 100, '%')
print("roc_auc_score:", roc_auc_score(y_test, y_prediction) * 100, '%')
# Out:
# SVM
#
# precision_score: 74.41077441077442 %
# recall_score: 68.20987654320987 %
# f1_score: 71.1755233494364 %
# roc_auc_score: 72.41263057929726 %

# %%
clf = RandomForestClassifier()
clf.fit(x_train, y_train)
y_prediction = clf.predict(x_test)

# %%
print("RandomForestClassifier", "\n")
print("precision_score:", precision_score(y_test, y_prediction) * 100, '%')
print("recall_score:", recall_score(y_test, y_prediction) * 100, '%')
print("f1_score:", f1_score(y_test, y_prediction) * 100, '%')
print("roc_auc_score:", roc_auc_score(y_test, y_prediction) * 100, '%')
# Out:
# RandomForestClassifier
#
# precision_score: 75.61728395061729 %
# recall_score: 75.61728395061729 %
# f1_score: 75.61728395061729 %
# roc_auc_score: 75.65479582146249 %

# %%
clf = GaussianNB()
clf.fit(x_train, y_train)
y_prediction = clf.predict(x_test)

# %%
print("GaussianNB", "\n")
print("precision_score:", precision_score(y_test, y_prediction) * 100, '%')
print("recall_score:", recall_score(y_test, y_prediction) * 100, '%')
print("f1_score:", f1_score(y_test, y_prediction) * 100, '%')
print("roc_auc_score:", roc_auc_score(y_test, y_prediction) * 100, '%')
# Out:
# GaussianNB
#
# precision_score: 51.70178282009724 %
# recall_score: 98.4567901234568 %
# f1_score: 67.80021253985123 %
# roc_auc_score: 53.38224121557455 %

# %%
import numpy as np
from copy import deepcopy

# %%
data_position = deepcopy(scaled_data)

for i in range(len(data)):
  for p in pos:
    if len(np.where(np.array(data.iloc[i]["pos_names"]) == p)[0]) == 0:
      data_position[p][i] = -1
    else:
      data_position[p][i] = round(np.where(np.array(data.iloc[i]["pos_names"]) == p)[0].sum() / len(data.iloc[i]["pos_names"]), 2)

# %%
data_position.head()
# Out:
#    result   AUX  PART   DET    X  CCONJ   NOUN   ADV    ADP  INTJ   PRON  \
# 0     1.0  0.57  1.76  3.00 -1.0   4.90  19.59  3.66   9.89  0.54  10.30
# 1     1.0  0.18  3.06  6.22  0.1   6.66  26.13  8.60   5.98 -1.00   3.56
# 2     0.0 -1.00  1.49  0.91 -1.0   2.38  17.37  2.38   3.66 -1.00   0.97
# 3     0.0  1.83  4.61  2.31 -1.0  11.55  46.75  7.03  12.67 -1.00   7.67
# 4     1.0 -1.00 -1.00  0.84 -1.0   2.21  11.47  0.28   2.72 -1.00   4.95
#
#      ADJ  PUNCT  PROPN  SYM   VERB  SPACE   NUM  SCONJ
# 0   3.74  18.06   5.20 -1.0  12.00  15.48 -1.00   1.32
# 1   8.11  29.33   3.40 -1.0  13.53  11.83 -1.00   1.32
# 2   6.22   8.61   2.15 -1.0   6.85  11.00 -1.00  -1.00
# 3  19.66  40.79  18.28 -1.0  19.15  33.96  4.24   6.99
# 4   6.10  10.22   0.07 -1.0   2.96   6.01 -1.00   0.66

# %%
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(data_position)
scaled_data = pd.DataFrame(data=scaled_features, columns=res_df.columns)
scaled_data.head()
# Out:
#    result       AUX      PART       DET        X     CCONJ      NOUN  \
# 0     1.0  0.057195  0.022688  0.038245  0.00000  0.028387  0.022349
# 1     1.0  0.042987  0.033374  0.069031  0.01405  0.036855  0.029447
# 2     0.0  0.000000  0.020469  0.018262  0.00000  0.016263  0.019939
# 3     0.0  0.103097  0.046116  0.031647  0.00000  0.060383  0.051828
# 4     1.0  0.000000  0.000000  0.017593  0.00000  0.015445  0.013535
#
#         ADV       ADP      INTJ      PRON       ADJ     PUNCT     PROPN  SYM  \
# 0  0.022685  0.034395  0.147087  0.037831  0.009645  0.014808  0.023492  0.0
# 1  0.046734  0.022045  0.000000  0.015266  0.018538  0.024339  0.016672  0.0
# 2  0.016454  0.014718  0.000000  0.006595  0.014692  0.006816  0.011935  0.0
# 3  0.039091  0.043175  0.000000  0.029026  0.042041  0.034031  0.073052  0.0
# 4  0.006231  0.011749  0.000000  0.019920  0.014448  0.008178  0.004054  0.0
#
#        VERB     SPACE       NUM     SCONJ
# 0  0.022736  0.020714  0.000000  0.046502
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(scaled_data.drop(["result"], axis=1), scaled_data["result"],
                                                    test_size=0.2, random_state=42)

# %%
clf = SVC()
clf.fit(x_train, y_train)
y_prediction = clf.predict(x_test)

# %%
print("SVM", "\n")
print("precision_score:", precision_score(y_test, y_prediction) * 100, '%')
print("recall_score:", recall_score(y_test, y_prediction) * 100, '%')
print("f1_score:", f1_score(y_test, y_prediction) * 100, '%')
print("roc_auc_score:", roc_auc_score(y_test, y_prediction) * 100, '%')
# Out:
# SVM
#
# precision_score: 72.49190938511327 %
# recall_score: 69.1358024691358 %
# f1_score: 70.7740916271722 %
# roc_auc_score: 71.49097815764482 %

# %%
clf = RandomForestClassifier()
clf.fit(x_train, y_train)
y_prediction = clf.predict(x_test)

# %%
print("RandomForestClassifier", "\n")
print("precision_score:", precision_score(y_test, y_prediction) * 100, '%')
print("recall_score:", recall_score(y_test, y_prediction) * 100, '%')
print("f1_score:", f1_score(y_test, y_prediction) * 100, '%')
print("roc_auc_score:", roc_auc_score(y_test, y_prediction) * 100, '%')
# Out:
# RandomForestClassifier
#
# precision_score: 75.39936102236422 %
# recall_score: 72.8395061728395 %
# f1_score: 74.09733124018838 %
# roc_auc_score: 74.57359924026592 %

# %%
clf = GaussianNB()
clf.fit(x_train, y_train)
y_prediction = clf.predict(x_test)

# %%
print("GaussianNB", "\n")
print("precision_score:", precision_score(y_test, y_prediction) * 100, '%')
print("recall_score:", recall_score(y_test, y_prediction) * 100, '%')
print("f1_score:", f1_score(y_test, y_prediction) * 100, '%')
print("roc_auc_score:", roc_auc_score(y_test, y_prediction) * 100, '%')
# Out:
# GaussianNB
#
# precision_score: 51.465798045602604 %
# recall_score: 97.53086419753086 %
# f1_score: 67.37739872068231 %
# roc_auc_score: 52.919278252611576 %
